# %%
import pandas as pd
import numpy as np

from pandas import Series,DataFrame

import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
FIFADATA=pd.read_csv('C:\\Users\\287910031\\FIFA19\\data.csv')

# %%
FIFADATA.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
FIFADATA.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
data=FIFADATA.copy()

# %%
data.head(28)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
# 15          15  211110          P. Dybala   24
# 16          16  202126            H. Kane   24
# 17          17  194765       A. Griezmann   27
# 18          18  192448      M. ter Stegen   26
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
###Analyzing National Team 

def country(x):
    return data[data['Nationality']==x][['Name','Age','Overall','Potential','Club','Position']]


country('Ghana')
# Out:
#                  Name  Age  Overall  Potential                      Club  \
# 249         T. Partey   25       82         88           Atlético Madrid
# 391        K. Boateng   31       81         81                  Sassuolo
# 679        K. Asamoah   29       79         79                     Inter
# 1118          A. Ayew   28       77         77             Fenerbahçe SK
# 1226    F. Acheampong   24       76         81           Tianjin TEDA FC
# 1237       E. Boateng   22       76         82                Levante UD
# 1393          J. Ayew   26       76         76            Crystal Palace
# 1570        G. Donsah   22       76         82                   Bologna
# 1700          E. Badu   27       75         75                   Udinese
# 1869       D. Amartey   23       75         79            Leicester City
# 1881        A. Duncan   25       75         80                  Sassuolo
# 1893        A. Adomah   30       75         75               Aston Villa
# ...

# %%
def club(x):
    return data[data['Club']==x][['Name','Nationality','Overall','Position','Jersey Number','Age','Wage','Release Clause',
                                  'Value','Contract Valid Until']]

club('Real Madrid')
# Out:
#                   Name         Nationality  Overall Position  Jersey Number  \
# 6            L. Modrić             Croatia       91      RCM           10.0
# 8         Sergio Ramos               Spain       91      RCB           15.0
# 11            T. Kroos             Germany       90      LCM            8.0
# 19         T. Courtois             Belgium       89       GK            1.0
# 27            Casemiro              Brazil       88      CDM           14.0
# 30                Isco               Spain       88       LW           22.0
# 35             Marcelo              Brazil       88       LB           12.0
# 36             G. Bale               Wales       88       ST           11.0
# 46            K. Navas          Costa Rica       87       GK            1.0
# 62           R. Varane              France       86      RCB            4.0
# 79       Marco Asensio               Spain       85       RW           10.0
# ...

# %%
x= club('Real Madrid')


x.shape
# Out:
# (33, 10)

# %%
total=data.isnull().sum().sort_values(ascending=False)
count=data.isnull().count().sort_values(ascending=False)

percentage=total/count

missing_value=pd.concat([total,percentage],axis=1,keys=['Total','Percentage'])
# Out:
# C:\Users\287910031\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %%
missing_value
# Out:
#                       Total  Percentage
# Acceleration             48    0.002636
# Age                       0    0.000000
# Aggression               48    0.002636
# Agility                  48    0.002636
# Balance                  48    0.002636
# BallControl              48    0.002636
# Body Type                48    0.002636
# CAM                    2085    0.114516
# CB                     2085    0.114516
# CDM                    2085    0.114516
# CF                     2085    0.114516
# CM                     2085    0.114516
# Club                    241    0.013237
# Club Logo                 0    0.000000
# Composure                48    0.002636
# Contract Valid Until    289    0.015873
# Crossing                 48    0.002636
# Curve                    48    0.002636
# Dribbling                48    0.002636
# FKAccuracy               48    0.002636
# Finishing                48    0.002636
# Flag                      0    0.000000
# ...

# %%
total
# Out:
# Loaned From             16943
# LWB                      2085
# LM                       2085
# CB                       2085
# LCB                      2085
# LB                       2085
# RWB                      2085
# RDM                      2085
# CDM                      2085
# LDM                      2085
# RM                       2085
# RCM                      2085
# CM                       2085
# LCM                      2085
# RAM                      2085
# RB                       2085
# CAM                      2085
# LAM                      2085
# RW                       2085
# RF                       2085
# CF                       2085
# LF                       2085
# LW                       2085
# RS                       2085
# ST                       2085
# LS                       2085
# RCB                      2085
# Release Clause           1564
# Joined                   1553
# Contract Valid Until      289
#                         ...
# ...

# %%
# filling the missing value for the continous variables for proper data visualization

data['ShortPassing'].fillna(data['ShortPassing'].mean(), inplace = True)
data['Volleys'].fillna(data['Volleys'].mean(), inplace = True)
data['Dribbling'].fillna(data['Dribbling'].mean(), inplace = True)
data['Curve'].fillna(data['Curve'].mean(), inplace = True)
data['FKAccuracy'].fillna(data['FKAccuracy'].mean(), inplace = True)
data['LongPassing'].fillna(data['LongPassing'].mean(), inplace = True)
data['BallControl'].fillna(data['BallControl'].mean(), inplace = True)
data['HeadingAccuracy'].fillna(data['HeadingAccuracy'].mean(), inplace = True)
data['Finishing'].fillna(data['Finishing'].mean(), inplace = True)
data['Crossing'].fillna(data['Crossing'].mean(), inplace = True)
data['Weight'].fillna('200lbs', inplace = True)
data['Contract Valid Until'].fillna(2019, inplace = True)
data['Height'].fillna("5'11", inplace = True)
data['Loaned From'].fillna('None', inplace = True)
data['Joined'].fillna('Jul 1, 2018', inplace = True)
data['Jersey Number'].fillna(20, inplace = True)
data['Body Type'].fillna('Normal', inplace = True)
data['Position'].fillna('ST', inplace = True)
data['Club'].fillna('No Club', inplace = True)
data['Work Rate'].fillna('Medium/ Medium', inplace = True)
data['Skill Moves'].fillna(data['Skill Moves'].median(), inplace = True)
data['Weak Foot'].fillna(3, inplace = True)
data['Preferred Foot'].fillna('Right', inplace = True)
data['International Reputation'].fillna(1, inplace = True)
data['Wage'].fillna('€200K', inplace = True)

# %%
data['Height'].fillna("5'11", inplace = True)

# %%
data.fillna(0,inplace=True)

# %%
FIFADATA.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
def defending(data):
    return int (round ((data[['Marking','StandingTackle','SlidingTackle']].mean()).mean()))

def general(data):
    return int (round ((data[['HeadingAccuracy','Dribbling','Curve','BallControl']].mean()).mean()))


def Mental(data):
    return int (round ((data[['Aggression','Interceptions','Position','Vision','Composure']].mean()).mean()))

def passing(data):
    return int(round((data[['Crossing', 'ShortPassing', 
                               'LongPassing']].mean()).mean()))

def mobility(data):
    return int(round((data[['Acceleration', 'SprintSpeed', 
                               'Agility','Reactions']].mean()).mean()))
def power(data):
    return int(round((data[['Balance', 'Jumping', 'Stamina', 
                               'Strength']].mean()).mean()))

def rating(data):
    return int(round((data[['Potential', 'Overall']].mean()).mean()))

def shooting(data):
    return int(round((data[['Finishing', 'Volleys', 'FKAccuracy', 
                               'ShotPower','LongShots', 'Penalties']].mean()).mean()))

# %%
plt.figure(figsize=(10,5))
sns.factorplot(x='Preferred Foot',data=data,kind='count')
plt.title('Most Preferred Foot in FIFA 19')
plt.show()

# %%
data['International Reputation'].value_counts()
# Out:
# 1.0    16580
# 2.0     1261
# 3.0      309
# 4.0       51
# 5.0        6
# Name: International Reputation, dtype: int64

# %%
###ploting a pie chat
labels=['1','2','3','4','5']
sizes=data['International Reputation'].value_counts()
explode=[0.1,0.1,0.2,0.5,0.9]

plt.figure(figsize=(9,9))

plt.pie(sizes,labels=labels,explode=explode,shadow=True)
plt.title('International Reputaion for FIFA19 Players')
plt.legend(loc='best')
plt.show()

# %%
data['Weak Foot'].value_counts()
# Out:
# 3.0    11397
# 2.0     3761
# 4.0     2662
# 5.0      229
# 1.0      158
# Name: Weak Foot, dtype: int64

# %%
labels=['5','4','3','2','1']
sizes=data['Weak Foot'].value_counts()
explode=[0,0,0,0,0.2]

plt.figure(figsize=(10,10))
plt.pie(sizes,labels=labels,explode=explode,shadow=True,startangle=90)
plt.title('Distribution of Weak Foot of Players in FIFA19')
plt.legend(loc='best')
plt.show()

# %%
###positions of players

plt.figure(figsize=(18,8))
sns.countplot(x='Position',data=data)
plt.xlabel('Different Positions')
plt.ylabel('Count of Players')
plt.title('Comparison of Positions and Players')
plt.show()

# %%
data['Position'].value_counts()
# Out:
# ST     2212
# GK     2025
# CB     1778
# CM     1394
# LB     1322
# RB     1291
# RM     1124
# LM     1095
# CAM     958
# CDM     948
# RCB     662
# LCB     648
# LCM     395
# RCM     391
# LW      381
# RW      370
# RDM     248
# LDM     243
# LS      207
# RS      203
# RWB      87
# LWB      78
# CF       74
# RAM      21
# LAM      21
# RF       16
# LF       15
# Name: Position, dtype: int64

# %%
x=lambda a: a + 10

print(x(5))
# Out:
# 15

# %%
#removing lbs
def extract_value_from(value):
    out= value.replace('lbs','')
    return float(out)
    
data['Weight']=data['Weight'].apply(lambda x:extract_value_from(x) )

# %%
data['Weight'].head()
# Out:
# 0    159.0
# 1    183.0
# 2    150.0
# 3    168.0
# 4    154.0
# Name: Weight, dtype: float64

# %%
##defining a function for cleaning the wage

def extract_value(value):
    out= value.replace('€','')
    if 'M' in out:
        out=float(out.replace ('M',''))*1000000
    elif 'K' in out:
        out= float(out.replace('K',''))*1000
    return float(out)

# %%
data['Value']=data['Value'].apply(lambda x:extract_value(x))

# %%
data['Wage'] = data['Wage'].apply(lambda x:extract_value(x))

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Wage'],color='blue')
plt.xlabel('Wage Range of Players')
plt.ylabel('Count of Players')
plt.title('Distribution of Wages of Players')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\287910031\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Skill Moves',data=data)
plt.xlabel('Skill Moves')
plt.ylabel('Count')
plt.title('Count of players on Basis of their skill moves')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Height',data=data)
plt.xlabel('Height in Foot per inch')
plt.ylabel('Count')
plt.title('Count of players on Basis of Height')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Weight'],color='blue')
plt.xlabel('Weight of Players')
plt.ylabel('Count of Players')
plt.title('Different Weights of the Players Participating in FIFA 2019')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\287910031\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Work Rate',data=data)
plt.xlabel('Work Rate of Players in FIFA 20')
plt.ylabel('Count')
plt.title('Different work rates of the Players Participating in the FIFA 2019')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Special'],bins=58,kde=False,color='m')
plt.xlabel('Special score range')
plt.ylabel('Count of the Players')
plt.title('Histogram for the Speciality Scores of the Players')
plt.show()
# Out:
# C:\Users\287910031\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Potential'],bins=58,kde=False,color='y')
plt.xlabel("Player\'s Potential Scores")
plt.ylabel('Number of  Players')
plt.title('Histogram of players Potential Scores')
plt.show()
# Out:
# C:\Users\287910031\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Overall'],bins=58,kde=False,color='y')
plt.xlabel("Player\'s Scores")
plt.ylabel('Number of  Players')
plt.title('Histogram of players Overall Scores')
plt.show()
# Out:
# C:\Users\287910031\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
data['Nationality'].value_counts().head(80).plot.bar(color='orange',figsize=(20,7))
plt.xlabel("Countries")
plt.ylabel('Count')
plt.title('First 80 Nations on FIFA rated by count')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Age'],bins=58,kde=False,color='g')
plt.xlabel("Player\'s Age")
plt.ylabel('Number of  Players')
plt.title('Histogram of players Age')
plt.show()
# Out:
# C:\Users\287910031\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
selected_columns = ['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
                    'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot',
                    'Skill Moves', 'Work Rate', 'Body Type', 'Position', 'Height', 'Weight',
                    'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
                    'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
                    'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
                    'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
                    'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
                    'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
                    'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause']

# %%
data_selected=DataFrame(data,columns=selected_columns)

# %%
data_selected.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Special', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Position',
#        'Height', 'Weight', 'Finishing', 'HeadingAccuracy', 'ShortPassing',
#        'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing',
#        'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions',
#        'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Release Clause'],
#       dtype='object')

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x=data['Overall'],y=data['Age'],hue=data['Preferred Foot'])
plt.title('AGE,OVERALL WITH PRFERRED FOOT')
# Out:
# Text(0.5,1,'AGE,OVERALL WITH PRFERRED FOOT')

# %%
data_selected.sample(5)
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 6213   P. Bartolomei   28       Italy       69         69
# 10074    L. Janoszka   31      Poland       65         65
# 15631      S. Wilson   25     England       59         62
# 1662    Hélder Costa   24    Portugal       75         81
# 11127    M. Perdijić   36     Croatia       64         64
#
#                           Club      Value     Wage  Special Preferred Foot  \
# 6213                    Spezia  1000000.0   3000.0     1892          Right
# 10074           Zagłębie Lubin   475000.0   2000.0     1793           Left
# 15631        Macclesfield Town   200000.0   2000.0     1387          Right
# 1662   Wolverhampton Wanderers  9000000.0  54000.0     1830           Left
# 11127       Zagłębie Sosnowiec    60000.0   1000.0     1107          Right
#
#             ...        Composure  Marking  StandingTackle SlidingTackle  \
# 6213        ...             64.0     59.0            59.0          57.0
# ...

# %%
plt.figure(figsize=(30,20))
sns.heatmap(data_selected.corr(),annot=True)

# %%
data.iloc[data.groupby(data['Position'])['Overall'].idxmax()][['Position','Name','Age','Club','Nationality','Overall']].style.background_gradient('Reds')
# Out:
# <style  type="text/css" >
#     #T_e96a4006_e233_11ea_a6ac_5ce0c5d61f22row0_col2 {
#             background-color:  #f44f39;
#         }    #T_e96a4006_e233_11ea_a6ac_5ce0c5d61f22row0_col5 {
#             background-color:  #ea362a;
#         }    #T_e96a4006_e233_11ea_a6ac_5ce0c5d61f22row1_col2 {
#             background-color:  #8a0812;
#         }    #T_e96a4006_e233_11ea_a6ac_5ce0c5d61f22row1_col5 {
#             background-color:  #d52221;
#         }    #T_e96a4006_e233_11ea_a6ac_5ce0c5d61f22row2_col2 {
#             background-color:  #d52221;
#         }    #T_e96a4006_e233_11ea_a6ac_5ce0c5d61f22row2_col5 {
#             background-color:  #ea362a;
#         }    #T_e96a4006_e233_11ea_a6ac_5ce0c5d61f22row3_col2 {
#             background-color:  #fc8161;
#         }    #T_e96a4006_e233_11ea_a6ac_5ce0c5d61f22row3_col5 {
#             background-color:  #fedbcc;
#         }    #T_e96a4006_e233_11ea_a6ac_5ce0c5d61f22row4_col2 {
#             background-color:  #f44f39;
# ...

# %%
data.iloc[data.groupby(data['Position'])['Potential'].idxmax()][['Position','Name','Age','Club','Nationality','Potential']].style.background_gradient('Blues')
# Out:
# <style  type="text/css" >
#     #T_285e6dac_e2d8_11ea_ae8c_5ce0c5d61f22row0_col2 {
#             background-color:  #6aaed6;
#         }    #T_285e6dac_e2d8_11ea_ae8c_5ce0c5d61f22row0_col5 {
#             background-color:  #3787c0;
#         }    #T_285e6dac_e2d8_11ea_ae8c_5ce0c5d61f22row1_col2 {
#             background-color:  #a4cce3;
#         }    #T_285e6dac_e2d8_11ea_ae8c_5ce0c5d61f22row1_col5 {
#             background-color:  #2070b4;
#         }    #T_285e6dac_e2d8_11ea_ae8c_5ce0c5d61f22row2_col2 {
#             background-color:  #6aaed6;
#         }    #T_285e6dac_e2d8_11ea_ae8c_5ce0c5d61f22row2_col5 {
#             background-color:  #4f9bcb;
#         }    #T_285e6dac_e2d8_11ea_ae8c_5ce0c5d61f22row3_col2 {
#             background-color:  #a4cce3;
#         }    #T_285e6dac_e2d8_11ea_ae8c_5ce0c5d61f22row3_col5 {
#             background-color:  #8dc1dd;
#         }    #T_285e6dac_e2d8_11ea_ae8c_5ce0c5d61f22row4_col2 {
#             background-color:  #bad6eb;
# ...

# %%
data['Nationality'].value_counts().head(8)
# Out:
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Brazil        827
# Italy         702
# Colombia      618
# Name: Nationality, dtype: int64

# %%
some_countries=('England','Germany','Spain','Argentina','France','Brazil','Italy','Colombia')

# %%
data_countries=data.loc[data['Nationality'].isin(some_countries)]

plt.figure(figsize=(15,7))
sns.violinplot(x=data_countries['Nationality'],y=data_countries['Weight'])
plt.xlabel('Nations')
plt.ylabel('Weight in lbs')
plt.title('Countries and Weight ')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.barplot(x=data_countries['Nationality'],y=data_countries['Overall'])
plt.xlabel('Nations')
plt.ylabel('Overal Rating of Players in the country')
plt.title('Countries and Overall ')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.barplot(x=data_countries['Nationality'],y=data_countries['Wage'])
plt.xlabel('Nations')
plt.ylabel('Wage')
plt.title('Countries and Wages ')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x=data_countries['Nationality'],y=data_countries['International Reputation'])
plt.xlabel('Nations')
plt.ylabel('INTERNATIONAL REPUTATION')
plt.title('NATIONS and INTERNATIONAL REPUTATION ')
plt.show()
