# %%
##WE HAVE TO OPEN THE FILE TRAIN AFTER WE HAVE IMPORTED FROM KARGGLE

import pandas as pd
import numpy as np 
from pandas import Series,DataFrame

import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

train_csv=pd.read_csv('C:\\Users\\287910031\\Desktop\\train.csv')

train_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_csv.info()

###in sql this is same as desc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
sns.factorplot(x='Sex',data=train_csv,kind='count')

####add kind 
###reason so for factor plots dey can do 'point, bar, count, box, violin, strip',kind shows which plot should be drawn

# %%
sns.factorplot(x='Sex',data=train_csv,kind='count',hue='Pclass')
##this allows us to add Pclass and tells us how many people where in a certain class

# %%
sns.factorplot(x='Pclass',data=train_csv,kind='count',hue='Sex')

# %%
def male_female_child(passenger):
    age,sex=passenger
    
    if age < 16:
        return'Child'
    else:
        return sex

# %%
train_csv[['Age','Sex']]
##to call two index this is how its done
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# 5     NaN    male
# 6    54.0    male
# 7     2.0    male
# 8    27.0  female
# 9    14.0  female
# 10    4.0  female
# 11   58.0  female
# 12   20.0    male
# 13   39.0    male
# 14   14.0  female
# 15   55.0  female
# 16    2.0    male
# 17    NaN    male
# 18   31.0  female
# 19    NaN  female
# 20   35.0    male
# 21   34.0    male
# 22   15.0  female
# 23   28.0    male
# 24    8.0  female
# 25   38.0  female
# 26    NaN    male
# 27   19.0    male
# 28    NaN  female
# 29    NaN    male
# ..    ...     ...
# 861  21.0    male
# 862  48.0  female
# 863   NaN  female
# 864  24.0    male
# 865  42.0  female
# 866  27.0  female
# 867  31.0    male
# 868   NaN    male
# 869   4.0    male
# 870  26.0    male
# 871  47.0  female
# 872  33.0    male
# 873  47.0    male
# 874  28.0  female
# 875  15.0  female
# 876  20.0    male
# 877  19.0    male
# 878   NaN    male
# ...

# %%
train_csv['Persons']=train_csv[['Age','Sex']].apply(male_female_child,axis=1)

# %%
train_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Persons
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
sns.factorplot(x='Pclass',data=train_csv,kind='count',hue='Persons')

# %%
train_csv['Age'].hist(bins=100)

##this worked because the syntax for hist in pandas is dataframe.hist

# %%
train_csv['Age'].mean()
# Out:
# 29.69911764705882

# %%
train_csv['Persons'].value_counts()
# Out:
# male      537
# female    271
# Child      83
# Name: Persons, dtype: int64

# %%
###using FaceGrid you must first call your FaceGrid then map it otherwise it won't display


oldest=train_csv['Age'].max()
oldest

fig=sns.FacetGrid(data=train_csv,hue='Sex',aspect=4,xlim=(0,oldest))

fig.map(sns.kdeplot,'Age',shade=True)

##to add legend

fig.add_legend()

# %%
fig=sns.FacetGrid(data=train_csv,hue='Persons',aspect=4,xlim=(0,oldest))

fig.map(sns.kdeplot,'Age',shade=True)

##to add legend

fig.add_legend()

# %%
fig=sns.FacetGrid(data=train_csv,hue='Pclass',aspect=4,xlim=(0,oldest))

fig.map(sns.kdeplot,'Age',shade=True)

##to add legend

fig.add_legend()

# %%
####QUESTION 2
#What deck were the passengers on #and how does that relate to their #class?

# %%
train_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Persons        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
deck=train_csv['Cabin'].dropna()

deck
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
# 21             D56
# 23              A6
# 27     C23 C25 C27
# 31             B78
# 52             D33
# 54             B30
# 55             C52
# 61             B28
# 62             C83
# 66             F33
# 75           F G73
# 88     C23 C25 C27
# 92             E31
# 96              A5
# 97         D10 D12
# 102            D26
# 110           C110
# 118        B58 B60
# 123           E101
# 124            D26
# 128          F E69
# 136            D47
# 137           C123
# 139            B86
# 148             F2
#           ...
# 751           E121
# 759            B77
# 763        B96 B98
# 765            D11
# 772            E77
# 776            F38
# 779             B3
# 781            B20
# 782             D6
# 789        B82 B84
# 796            D17
# 802        B96 B98
# 806            A36
# 809             E8
# 815           B102
# 820            B69
# ...

# %%
levels=[]

for level in deck:
    levels.append(level[0])
    

levels

cabin_df=DataFrame(levels)

cabin_df.columns=['Cabin']

cabin_df=cabin_df[cabin_df.Cabin!='T']
cabin_df

sns.factorplot(data=cabin_df,kind='count',x='Cabin')

# %%
train_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Persons        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.factorplot(data=train_csv,x='Embarked',hue='Pclass',kind='count')

# %%
train_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Persons
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
q=train_csv['SibSp'] + train_csv['Parch']

train_csv['Alone']=q

train_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Persons  Alone
# 0      0         A/5 21171   7.2500   NaN        S    male      1
# 1      0          PC 17599  71.2833   C85        C  female      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female      0
# ...

# %%
train_csv['Alone'].loc[train_csv['Alone']> 0]='With Family'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-bcf01c6de3eb> in <module>()
# ----> 1 train_csv['Alone'].loc[train_csv['Alone']> 0]='With Family'
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1251
#    1252             with np.errstate(all='ignore'):
# -> 1253                 res = na_op(values, other)
#    1254             if is_scalar(res):
#    1255                 raise TypeError('Could not compare {typ} type with Series'
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1138
#    1139         elif is_object_dtype(x.dtype):
# -> 1140             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1141
#    1142         elif is_datetimelike_v_numeric(x, y):
#
# ...

# %%
train_csv['Alone'].loc[train_csv['Alone']==0]='Alone'

# %%
train_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Persons        Alone
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.factorplot(x='Alone',kind='count',data=train_csv)

# %%
train_csv['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
train_csv['Survivor']=train_csv['Survived']

train_csv['Survivor'].loc[train_csv['Survivor']==0]='No'
train_csv['Survivor'].loc[train_csv['Survivor']==1]='Yes'
# Out:
# C:\Users\287910031\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
train_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Persons        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
###or you can do a mapping
train_csv['MapSurvivor']=train_csv['Survived'].map({0:'No',1:'Yes'})

# %%
train_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Persons        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.factorplot(data=train_csv,x='MapSurvivor',kind='count',hue='Sex')

# %%
sns.factorplot(x='Pclass',y='Survived',data=train_csv,kind='point')

####for x and y you do not do kind=count 
#kind can be point,violin,strip,bar

# %%
sns.factorplot(x='Pclass',y='Survived',data=train_csv,kind='point',hue='Persons')

# %%
sns.lmplot(x='Age',y='Survived',data=train_csv)

# %%
sns.lmplot(x='Age',y='Survived',data=train_csv,hue='Pclass')

# %%
sns.lmplot(x='Age',y='Survived',data=train_csv,hue='Sex')

# %%
train_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Persons        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.factorplot(x='Alone',y='Survived',data=train_csv,kind='point',hue='Persons')
