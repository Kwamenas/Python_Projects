# %%
import pandas as pd
import numpy as np
import os
from pandas import Series,DataFrame

import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
import datetime 
import requests
import io

# %%
URL='http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama.csv'

##SOURCE=requests.get(URL).text

##POLL_DATA=io.StringIO(SOURCE)

# %%
###strategy 1
###easier way 
poll_data=pd.read_csv(URL)
poll_data.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
###strategy2 io
SOURCE=requests.get(URL).text
#new_polls=io.StringIO(SOURCE)


new_polls=pd.read_csv(io.StringIO(SOURCE))

# %%
new_polls.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
new_polls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 17 columns):
# Pollster                  586 non-null object
# Start Date                586 non-null object
# End Date                  586 non-null object
# Entry Date/Time (ET)      586 non-null object
# Number of Observations    564 non-null float64
# Population                586 non-null object
# Mode                      586 non-null object
# Obama                     586 non-null float64
# Romney                    586 non-null float64
# Undecided                 423 non-null float64
# Other                     202 non-null float64
# Pollster URL              586 non-null object
# Source URL                584 non-null object
# Partisan                  586 non-null object
# Affiliation               586 non-null object
# Question Text             0 non-null float64
# Question Iteration        586 non-null int64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 77.9+ KB

# %%
sns.factorplot(x='Affiliation',data=poll_data,kind='count')

# %%
sns.factorplot(x='Affiliation',data=poll_data,kind='count',hue='Population')

# %%
poll_data.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
avg=DataFrame(poll_data.mean())
###avg.drop('Number of Observations',inplace=True) droping for one index

###['Number of Observations','Other','Question Text','Question Iteration'] from multiple index

avg.drop(['Number of Observations','Other','Question Text','Question Iteration'],inplace=True)

avg
# Out:
#                    0
# Obama      46.805461
# Romney     44.614334
# Undecided   6.550827

# %%
stde=DataFrame(poll_data.std())

stde.drop(['Number of Observations','Other','Question Text','Question Iteration'],inplace=True)

stde
# Out:
#                   0
# Obama      2.422058
# Romney     2.906180
# Undecided  3.701754

# %%
avg.plot(yerr=stde,kind='bar',legend=False)

###checl plot for pyhon youll understand yerr
###plt.plot is different from .plot

# %%
poll_avg_std=pd.concat([avg,stde],axis=1)

poll_avg_std.columns=['Average','Std']

poll_avg_std
# Out:
#              Average       Std
# Obama      46.805461  2.422058
# Romney     44.614334  2.906180
# Undecided   6.550827  3.701754

# %%
poll_data.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
poll_data.plot(x='End Date',y=['Obama','Romney','Undecided'],linestyle='',marker='o')

# %%
poll_data['Difference']=(poll_data.Obama-poll_data.Romney)/100

poll_data.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
A=poll_data.groupby(['Start Date'],as_index=False).mean()

A.head()
# Out:
#    Start Date  Number of Observations  Obama  Romney  Undecided  Other  \
# 0  2009-03-13                  1403.0   44.0    44.0       12.0    NaN
# 1  2009-04-17                   686.0   50.0    39.0       11.0    NaN
# 2  2009-05-14                  1000.0   53.0    35.0       12.0    NaN
# 3  2009-06-12                   638.0   48.0    40.0       12.0    NaN
# 4  2009-07-15                   577.0   49.0    40.0       11.0    NaN
#
#    Question Text  Question Iteration  Difference
# 0            NaN                   1        0.00
# 1            NaN                   1        0.11
# 2            NaN                   1        0.18
# 3            NaN                   1        0.08
# 4            NaN                   1        0.09

# %%
A.plot('Start Date','Difference',figsize=(10,4),linestyle='-',marker='o')

# %%
row_in=0
xlimit=[]

for date in A['Start Date']:
    if date[0:7]=='2012-10':
        xlimit.append(row_in)
        row_in +=1
        
    else:
        row_in +=1
        
    


        
print(max(xlimit))
print(min(xlimit))
# Out:
# 352
# 325

# %%
A.plot('Start Date','Difference',figsize=(10,4),linestyle='-',marker='o',xlim=(325,352))

plt.axvline(x=325+2,linewidth=4,color='grey')

plt.axvline(x=325+10,linewidth=4,color='grey')

plt.axvline(x=325+21,linewidth=4,color='grey')

# %%
pwd
# Out:
# 'C:\\Users\\287910031'

# %%
donor_df=pd.read_csv('Election_Donor_Data.csv')
# Out:
# C:\Users\287910031\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
donor_df.head(10)
# Out:
#      cmte_id    cand_id             cand_nm           contbr_nm  \
# 0  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 1  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 2  C00410118  P20002978  Bachmann, Michelle       SMITH, LANIER
# 3  C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 4  C00410118  P20002978  Bachmann, Michelle  WARDENBURG, HAROLD
# 5  C00410118  P20002978  Bachmann, Michelle      BECKMAN, JAMES
# 6  C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 7  C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 8  C00410118  P20002978  Bachmann, Michelle      COLLINS, SARAH
# 9  C00410118  P20002978  Bachmann, Michelle     COLEMAN, RONALD
#
#           contbr_city contbr_st   contbr_zip        contbr_employer  \
# 0              MOBILE        AL   3.6601e+08                RETIRED
# 1              MOBILE        AL   3.6601e+08                RETIRED
# ...

# %%
donor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001731 entries, 0 to 1001730
# Data columns (total 16 columns):
# cmte_id              1001731 non-null object
# cand_id              1001731 non-null object
# cand_nm              1001731 non-null object
# contbr_nm            1001731 non-null object
# contbr_city          1001712 non-null object
# contbr_st            1001727 non-null object
# contbr_zip           1001620 non-null object
# contbr_employer      988002 non-null object
# contbr_occupation    993301 non-null object
# contb_receipt_amt    1001731 non-null float64
# contb_receipt_dt     1001731 non-null object
# receipt_desc         14166 non-null object
# memo_cd              92482 non-null object
# memo_text            97770 non-null object
# form_tp              1001731 non-null object
# file_num             1001731 non-null int64
# dtypes: float64(1), int64(1), object(14)
# memory usage: 122.3+ MB

# %%
donor_df['contb_receipt_amt'].value_counts()
# Out:
#  100.00     178188
#  50.00      137584
#  25.00      110345
#  250.00      91182
#  500.00      57984
#  2500.00     49005
#  35.00       37237
#  1000.00     36494
#  10.00       33986
#  200.00      27813
#  20.00       17565
#  15.00       16163
#  150.00      14600
#  75.00       13647
#  201.20      11718
#  30.00       11381
#  300.00      11204
#  20.12        9897
#  5.00         9024
#  40.00        5007
#  2000.00      4128
#  55.00        3760
#  1500.00      3705
#  3.00         3383
#  60.00        3084
#  400.00       3066
# -2500.00      2727
#  110.00       2554
#  125.00       2520
#  19.00        2474
#              ...
#  174.80          1
#  7.27            1
#  1219.00         1
#  1884.88         1
#  162.25          1
#  218.31          1
#  78.62           1
#  203.16          1
#  53.11           1
#  499.66          1
#  19.53           1
#  188.60          1
#  47.10           1
#  19.85           1
#  28.83           1
#  202.59          1
# ...

# %%
donor_mean=donor_df['contb_receipt_amt'].mean()


donor_std=donor_df['contb_receipt_amt'].std()

print('the average  donated amount is %.2f, and standard deviation is %.2f'  %(donor_mean,donor_std))
# Out:
# the average  donated amount is 298.24, and standard deviation is 3749.67

# %%
top_donor=donor_df['contb_receipt_amt']

top_donor.sort_values()
# Out:
# 114604     -30800.00
# 226986     -25800.00
# 101356      -7500.00
# 398429      -5500.00
# 250737      -5455.00
# 33821       -5414.31
# 908565      -5115.00
# 456649      -5000.00
# 574657      -5000.00
# 30513       -5000.00
# 562267      -5000.00
# 30584       -5000.00
# 86268       -5000.00
# 708920      -5000.00
# 665887      -5000.00
# 708899      -5000.00
# 708929      -5000.00
# 21172       -5000.00
# 21168       -5000.00
# 21167       -5000.00
# 262328      -5000.00
# 946875      -5000.00
# 7361        -5000.00
# 416403      -5000.00
# 21164       -5000.00
# 707945      -5000.00
# 615101      -5000.00
# 7973        -5000.00
# 54430       -5000.00
# 54434       -5000.00
#              ...
# 708022      10000.00
# 708898      10000.00
# 710177      10000.00
# 876244      10000.00
# 709608      10000.00
# 708919      10000.00
# 709739      10000.00
# 91145       10000.00
# 708138      10000.00
# 993178      10000.00
# 709813      10000.00
# 710730      10000.00
# ...

# %%
top_donor=top_donor[top_donor > 0]

top_donor
# Out:
# 0           250.0
# 1            50.0
# 2           250.0
# 3           250.0
# 4           300.0
# 5           500.0
# 6           250.0
# 7           250.0
# 8           250.0
# 9           250.0
# 10          250.0
# 11          500.0
# 12          250.0
# 13          250.0
# 14          250.0
# 15          300.0
# 16          500.0
# 17         1000.0
# 18          250.0
# 19          300.0
# 20          500.0
# 21          250.0
# 22         2500.0
# 23         2500.0
# 24          150.0
# 25          200.0
# 26          100.0
# 27          250.0
# 28          500.0
# 29          250.0
#             ...
# 1001696    1000.0
# 1001697    1500.0
# 1001698    2500.0
# 1001699    2500.0
# 1001700     300.0
# 1001701    2500.0
# 1001702    2500.0
# 1001705    1000.0
# 1001706    2500.0
# 1001708    2500.0
# 1001711    1000.0
# 1001712    2500.0
# 1001713    2500.0
# 1001714     250.0
# 1001715     250.0
# 1001716    1000.0
# 1001717     100.0
# 1001718    2500.0
# 1001719    2500.0
# ...

# %%
top_donor.value_counts().head(10)
# Out:
# 100.0     178188
# 50.0      137584
# 25.0      110345
# 250.0      91182
# 500.0      57984
# 2500.0     49005
# 35.0       37237
# 1000.0     36494
# 10.0       33986
# 200.0      27813
# Name: contb_receipt_amt, dtype: int64

# %%
cmon_donr=top_donor[top_donor > 25000]

cmon_donr
# Out:
# 114754      33300.00
# 217891      25800.00
# 257270     451726.00
# 319478     526246.17
# 325136    2014490.51
# 326651    1944042.43
# 335187     512710.91
# 344419    1511192.17
# 344539    1679114.65
# Name: contb_receipt_amt, dtype: float64

# %%
cmon_donr.hist(bins=100)

# %%
donor_df.head()
# Out:
#      cmte_id    cand_id             cand_nm           contbr_nm  \
# 0  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 1  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 2  C00410118  P20002978  Bachmann, Michelle       SMITH, LANIER
# 3  C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 4  C00410118  P20002978  Bachmann, Michelle  WARDENBURG, HAROLD
#
#           contbr_city contbr_st   contbr_zip        contbr_employer  \
# 0              MOBILE        AL   3.6601e+08                RETIRED
# 1              MOBILE        AL   3.6601e+08                RETIRED
# 2              LANETT        AL  3.68633e+08  INFORMATION REQUESTED
# 3             PIGGOTT        AR  7.24548e+08                   NONE
# 4  HOT SPRINGS NATION        AR  7.19016e+08                   NONE
#
#        contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 0                RETIRED              250.0        20-JUN-11          NaN
# ...

# %%
candidate=donor_df.cand_nm.unique()

candidate
# Out:
# array(['Bachmann, Michelle', 'Romney, Mitt', 'Obama, Barack',
#        "Roemer, Charles E. 'Buddy' III", 'Pawlenty, Timothy',
#        'Johnson, Gary Earl', 'Paul, Ron', 'Santorum, Rick',
#        'Cain, Herman', 'Gingrich, Newt', 'McCotter, Thaddeus G',
#        'Huntsman, Jon', 'Perry, Rick'], dtype=object)

# %%
for i in range(0,len(donor_df)):
    if donor_df['cand_nm'][i]=='Obama,Barak':
        print (i)
# Out:
#   File "<ipython-input-60-4069e9181e29>", line 2
#     if donor_df['cand_nm'][i]=='Obama,Barak'
#                                             ^
# SyntaxError: invalid syntax

# %%
####whiles we explore lets look at using dictionary and map for this 

party_map={'Bachmann, Michelle': 'Republican',
           'Cain, Herman': 'Republican',
           'Gingrich, Newt': 'Republican',
           'Huntsman, Jon': 'Republican',
           'Johnson, Gary Earl': 'Republican',
           'McCotter, Thaddeus G': 'Republican',
           'Obama, Barack': 'Democrat',
           'Paul, Ron': 'Republican',
           'Pawlenty, Timothy': 'Republican',
           'Perry, Rick': 'Republican',
           "Roemer, Charles E. 'Buddy' III": 'Republican',
           'Romney, Mitt': 'Republican',
           'Santorum, Rick': 'Republican'}

donor_df['Party']=donor_df.cand_nm.map(party_map)

# %%
donor_df.head()
# Out:
#      cmte_id    cand_id             cand_nm           contbr_nm  \
# 0  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 1  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 2  C00410118  P20002978  Bachmann, Michelle       SMITH, LANIER
# 3  C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 4  C00410118  P20002978  Bachmann, Michelle  WARDENBURG, HAROLD
#
#           contbr_city contbr_st   contbr_zip        contbr_employer  \
# 0              MOBILE        AL   3.6601e+08                RETIRED
# 1              MOBILE        AL   3.6601e+08                RETIRED
# 2              LANETT        AL  3.68633e+08  INFORMATION REQUESTED
# 3             PIGGOTT        AR  7.24548e+08                   NONE
# 4  HOT SPRINGS NATION        AR  7.19016e+08                   NONE
#
#        contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 0                RETIRED              250.0        20-JUN-11          NaN
# ...

# %%
b=donor_df.groupby('cand_nm')['contb_receipt_amt'].sum()
b
# Out:
# cand_nm
# Bachmann, Michelle                2.677435e+06
# Cain, Herman                      7.047265e+06
# Gingrich, Newt                    1.201183e+07
# Huntsman, Jon                     3.204350e+06
# Johnson, Gary Earl                5.669616e+05
# McCotter, Thaddeus G              3.703000e+04
# Obama, Barack                     1.335026e+08
# Paul, Ron                         2.072257e+07
# Pawlenty, Timothy                 4.255054e+06
# Perry, Rick                       1.841151e+07
# Roemer, Charles E. 'Buddy' III    3.674575e+05
# Romney, Mitt                      8.521925e+07
# Santorum, Rick                    1.072809e+07
# Name: contb_receipt_amt, dtype: float64

# %%
i=0
for don in b:
    print('Candidate %s,had %.f donations'%(b.index[i],don))
    print ('\n')
    i +=1
# Out:
# Candidate Bachmann, Michelle,had 2677435 donations
#
#
# Candidate Cain, Herman,had 7047265 donations
#
#
# Candidate Gingrich, Newt,had 12011832 donations
#
#
# Candidate Huntsman, Jon,had 3204350 donations
#
#
# Candidate Johnson, Gary Earl,had 566962 donations
#
#
# Candidate McCotter, Thaddeus G,had 37030 donations
#
#
# Candidate Obama, Barack,had 133502591 donations
#
#
# Candidate Paul, Ron,had 20722567 donations
#
#
# Candidate Pawlenty, Timothy,had 4255054 donations
#
#
# Candidate Perry, Rick,had 18411512 donations
#
#
# Candidate Roemer, Charles E. 'Buddy' III,had 367458 donations
#
#
# Candidate Romney, Mitt,had 85219249 donations
#
#
# Candidate Santorum, Rick,had 10728090 donations

# %%
b.plot(kind='bar')

# %%
Party_details=donor_df.groupby('Party')['contb_receipt_amt'].sum()

# %%
Party_details.plot(kind='bar')

# %%
donor_df.head()
# Out:
#      cmte_id    cand_id             cand_nm           contbr_nm  \
# 0  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 1  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 2  C00410118  P20002978  Bachmann, Michelle       SMITH, LANIER
# 3  C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 4  C00410118  P20002978  Bachmann, Michelle  WARDENBURG, HAROLD
#
#           contbr_city contbr_st   contbr_zip        contbr_employer  \
# 0              MOBILE        AL   3.6601e+08                RETIRED
# 1              MOBILE        AL   3.6601e+08                RETIRED
# 2              LANETT        AL  3.68633e+08  INFORMATION REQUESTED
# 3             PIGGOTT        AR  7.24548e+08                   NONE
# 4  HOT SPRINGS NATION        AR  7.19016e+08                   NONE
#
#        contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 0                RETIRED              250.0        20-JUN-11          NaN
# ...

# %%
occupation_df=donor_df.pivot_table('contb_receipt_amt',index='contbr_occupation',columns='Party',aggfunc='sum')

occupation_df.head()
# Out:
# Party                                Democrat  Republican
# contbr_occupation
#    MIXED-MEDIA ARTIST / STORYTELLER     100.0         NaN
#  AREA VICE PRESIDENT                    250.0         NaN
#  RESEARCH ASSOCIATE                     100.0         NaN
#  TEACHER                                500.0         NaN
#  THERAPIST                             3900.0         NaN

# %%
occupation_df=occupation_df[occupation_df.sum(1)>1000000]

# %%
occupation_df.plot(kind='bar',figsize=(10,12))

# %%
occupation_df.plot(kind='barh',figsize=(10,12))

# %%
occupation_df.drop(['INFORMATION REQUESTED PER BEST EFFORTS','INFORMATION REQUESTED'])
# Out:
# Party                 Democrat    Republican
# contbr_occupation
# ATTORNEY           11126932.97  7.343540e+06
# BANKER               224084.40  1.238819e+06
# BUSINESS OWNER       449979.30  1.286532e+06
# C.E.O.                 1690.00  2.431528e+06
# CEO                 2069784.79  1.501157e+06
# CHAIRMAN             495547.00  1.196048e+06
# CONSULTANT          2459812.71  2.472815e+06
# ENGINEER             950425.55  1.780102e+06
# EXECUTIVE           1355161.05  3.918557e+06
# FINANCE              294031.40  1.369990e+06
# HOMEMAKER           4243394.30  1.324141e+07
# INVESTMENTS          160480.00  9.604679e+05
# INVESTOR             884133.00  2.320349e+06
# LAWYER              3159391.87  3.785903e+05
# MANAGER              762693.22  1.404878e+06
# NOT EMPLOYED        1708108.20  4.481973e+04
# OWNER                998867.36  2.279621e+06
# PARTNER              395759.50  7.818971e+05
# PHYSICIAN           3732387.44  3.491657e+06
# ...

# %%
occupation_df.loc['CEO']=occupation_df.loc['CEO']+occupation_df.loc['C.E.O.']

occupation_df.drop('C.E.O.')
# Out:
# Party                                      Democrat    Republican
# contbr_occupation
# ATTORNEY                                11126932.97  7.343540e+06
# BANKER                                    224084.40  1.238819e+06
# BUSINESS OWNER                            449979.30  1.286532e+06
# CEO                                      2073164.79  6.364214e+06
# CHAIRMAN                                  495547.00  1.196048e+06
# CONSULTANT                               2459812.71  2.472815e+06
# ENGINEER                                  950425.55  1.780102e+06
# EXECUTIVE                                1355161.05  3.918557e+06
# FINANCE                                   294031.40  1.369990e+06
# HOMEMAKER                                4243394.30  1.324141e+07
# INFORMATION REQUESTED                    4849801.96  3.892556e+06
# INFORMATION REQUESTED PER BEST EFFORTS          NaN  1.585951e+07
# INVESTMENTS                               160480.00  9.604679e+05
# ...

# %%
occupation_df.plot(kind='barh',figsize=(10,12))
