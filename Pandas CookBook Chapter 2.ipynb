# %%
# %matplotlib inline
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
movie_df=pd.read_csv('C:\\Users\\287910031\9781839213106_Code\\data\\movie.csv')

# %%
movie_df[["actor_1_name","actor_2_name","actor_3_name","director_name"]].head()
# Out:
#       actor_1_name      actor_2_name          actor_3_name      director_name
# 0      CCH Pounder  Joel David Moore             Wes Studi      James Cameron
# 1      Johnny Depp     Orlando Bloom        Jack Davenport     Gore Verbinski
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman         Sam Mendes
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt  Christopher Nolan
# 4      Doug Walker        Rob Walker                   NaN        Doug Walker

# %%
type(movie_df['actor_1_name'])
# Out:
# pandas.core.series.Series

# %%
type(movie_df[['actor_1_name']])
# Out:
# pandas.core.frame.DataFrame

# %%
movie_df.loc[:,['actor_3_name','actor_1_name']].head()
# Out:
#            actor_3_name     actor_1_name
# 0             Wes Studi      CCH Pounder
# 1        Jack Davenport      Johnny Depp
# 2      Stephanie Sigman  Christoph Waltz
# 3  Joseph Gordon-Levitt        Tom Hardy
# 4                   NaN      Doug Walker

# %%
cols=["actor_1_name","actor_2_name","actor_3_name","director_name"]

movie_df[cols].head()
# Out:
#       actor_1_name      actor_2_name          actor_3_name      director_name
# 0      CCH Pounder  Joel David Moore             Wes Studi      James Cameron
# 1      Johnny Depp     Orlando Bloom        Jack Davenport     Gore Verbinski
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman         Sam Mendes
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt  Christopher Nolan
# 4      Doug Walker        Rob Walker                   NaN        Doug Walker

# %%
a='_for_reviews'

a.replace('_for_reviews','')
# Out:
# ''

# %%
def shorten(col):
    return (col.replace('facebook_likes','fb').replace('_for_reviews','') )

# %%
muv=movie_df.rename(columns=shorten)

# %%
[c.replace('facebook_like','fb') for c in movie_df.columns if 'facebook_likes' in c]
# Out:
# ['director_fbs',
#  'actor_3_fbs',
#  'actor_1_fbs',
#  'cast_total_fbs',
#  'actor_2_fbs',
#  'movie_fbs']

# %%
muv.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# dtype: int64

# %%
muv.select_dtypes(include='int64').head()
# Out:
#    num_voted_users  cast_total_fb  movie_fb
# 0           886204           4834     33000
# 1           471220          48350         0
# 2           275868          11700     85000
# 3          1144337         106759    164000
# 4                8            143         0

# %%
muv.select_dtypes(include='number').head()
# Out:
#    num_critic  duration  director_fb  actor_3_fb  actor_1_fb        gross  \
# 0       723.0     178.0          0.0       855.0      1000.0  760505847.0
# 1       302.0     169.0        563.0      1000.0     40000.0  309404152.0
# 2       602.0     148.0          0.0       161.0     11000.0  200074175.0
# 3       813.0     164.0      22000.0     23000.0     27000.0  448130642.0
# 4         NaN       NaN        131.0         NaN       131.0          NaN
#
#    num_voted_users  cast_total_fb  facenumber_in_poster  num_user  \
# 0           886204           4834                   0.0    3054.0
# 1           471220          48350                   0.0    1238.0
# 2           275868          11700                   1.0     994.0
# 3          1144337         106759                   0.0    2701.0
# 4                8            143                   0.0       NaN
#
#         budget  title_year  actor_2_fb  imdb_score  aspect_ratio  movie_fb
# ...

# %%
muv.select_dtypes(exclude='float64').head()
# Out:
#    color      director_name      actor_2_name  \
# 0  Color      James Cameron  Joel David Moore
# 1  Color     Gore Verbinski     Orlando Bloom
# 2  Color         Sam Mendes      Rory Kinnear
# 3  Color  Christopher Nolan    Christian Bale
# 4    NaN        Doug Walker        Rob Walker
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                   movie_title  num_voted_users  cast_total_fb  \
# 0                                      Avatar           886204           4834
# 1    Pirates of the Caribbean: At World's End           471220          48350
# 2                                     Spectre           275868          11700
# ...

# %%
muv.select_dtypes(exclude=['float64','int64']).head()
# Out:
#    color      director_name      actor_2_name  \
# 0  Color      James Cameron  Joel David Moore
# 1  Color     Gore Verbinski     Orlando Bloom
# 2  Color         Sam Mendes      Rory Kinnear
# 3  Color  Christopher Nolan    Christian Bale
# 4    NaN        Doug Walker        Rob Walker
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                   movie_title          actor_3_name  \
# 0                                      Avatar             Wes Studi
# 1    Pirates of the Caribbean: At World's End        Jack Davenport
# 2                                     Spectre      Stephanie Sigman
# 3                       The Dark Knight Rises  Joseph Gordon-Levitt
# ...

# %%
muv.filter(like='fb').head()
# Out:
#    director_fb  actor_3_fb  actor_1_fb  cast_total_fb  actor_2_fb  movie_fb
# 0          0.0       855.0      1000.0           4834       936.0     33000
# 1        563.0      1000.0     40000.0          48350      5000.0         0
# 2          0.0       161.0     11000.0          11700       393.0     85000
# 3      22000.0     23000.0     27000.0         106759     23000.0    164000
# 4        131.0         NaN       131.0            143        12.0         0

# %%
muv.filter(items=cols).head()
# Out:
#       actor_1_name      actor_2_name          actor_3_name      director_name
# 0      CCH Pounder  Joel David Moore             Wes Studi      James Cameron
# 1      Johnny Depp     Orlando Bloom        Jack Davenport     Gore Verbinski
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman         Sam Mendes
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt  Christopher Nolan
# 4      Doug Walker        Rob Walker                   NaN        Doug Walker

# %%
muv.filter(regex=r'\d').head()
# Out:
#    actor_3_fb      actor_2_name  actor_1_fb     actor_1_name  \
# 0       855.0  Joel David Moore      1000.0      CCH Pounder
# 1      1000.0     Orlando Bloom     40000.0      Johnny Depp
# 2       161.0      Rory Kinnear     11000.0  Christoph Waltz
# 3     23000.0    Christian Bale     27000.0        Tom Hardy
# 4         NaN        Rob Walker       131.0      Doug Walker
#
#            actor_3_name  actor_2_fb
# 0             Wes Studi       936.0
# 1        Jack Davenport      5000.0
# 2      Stephanie Sigman       393.0
# 3  Joseph Gordon-Levitt     23000.0
# 4                   NaN        12.0

# %%
def shorten(col):
    return(col.replace('faa','fb').replace('view',''))

# %%
muv.columns
# Out:
# Index(['color', 'director_name', 'num_critic', 'duration', 'director_fb',
#        'actor_3_fb', 'actor_2_name', 'actor_1_fb', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users', 'cast_total_fb',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_fb', 'imdb_score', 'aspect_ratio',
#        'movie_fb'],
#       dtype='object')

# %%
cat_core=['movie_title','title_year','content_rating','genres']
cat_people=["director_name", "actor_1_name","actor_2_name","actor_3_name"]
cat_other=["color","country","language", "plot_keywords","movie_imdb_link"]

cont_fb=["director_fb","actor_1_fb","actor_2_fb","actor_3_fb","cast_total_fb", "movie_fb"]
cont_finance = ["budget", "gross"]
cont_num_reviews=["num_voted_users","num_user","num_critic"]
cont_other=["imdb_score","duration","aspect_ratio","facenumber_in_poster"]

# %%
new_order= cat_core+cat_people+cat_other+cont_fb+cont_finance+cont_num_reviews+cont_other

# %%
set(muv.columns)==set(new_order)
# Out:
# True

# %%
muv[new_order].head()
# Out:
#                                   movie_title  title_year content_rating  \
# 0                                      Avatar      2009.0          PG-13
# 1    Pirates of the Caribbean: At World's End      2007.0          PG-13
# 2                                     Spectre      2015.0          PG-13
# 3                       The Dark Knight Rises      2012.0          PG-13
# 4  Star Wars: Episode VII - The Force Awakens         NaN            NaN
#
#                             genres      director_name     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      James Cameron      CCH Pounder
# 1         Action|Adventure|Fantasy     Gore Verbinski      Johnny Depp
# 2        Action|Adventure|Thriller         Sam Mendes  Christoph Waltz
# 3                  Action|Thriller  Christopher Nolan        Tom Hardy
# 4                      Documentary        Doug Walker      Doug Walker
#
#        actor_2_name          actor_3_name  color country  \
# ...

# %%
movie_df.size
# Out:
# 137648

# %%
movie_df.shape
# Out:
# (4916, 28)

# %%
len(movie_df)
# Out:
# 4916

# %%
movie_df.count()
# Out:
# color                        4897
# director_name                4814
# num_critic_for_reviews       4867
# duration                     4901
# director_facebook_likes      4814
# actor_3_facebook_likes       4893
# actor_2_name                 4903
# actor_1_facebook_likes       4909
# gross                        4054
# genres                       4916
# actor_1_name                 4909
# movie_title                  4916
# num_voted_users              4916
# cast_total_facebook_likes    4916
# actor_3_name                 4893
# facenumber_in_poster         4903
# plot_keywords                4764
# movie_imdb_link              4916
# num_user_for_reviews         4895
# language                     4904
# country                      4911
# content_rating               4616
# budget                       4432
# title_year                   4810
# actor_2_facebook_likes       4903
# imdb_score                   4916
# aspect_ratio                 4590
# ...

# %%
movie_df.describe().T
# Out:
#                             count          mean           std      min  \
# num_critic_for_reviews     4867.0  1.379889e+02  1.202394e+02     1.00
# duration                   4901.0  1.070908e+02  2.528602e+01     7.00
# director_facebook_likes    4814.0  6.910145e+02  2.832954e+03     0.00
# actor_3_facebook_likes     4893.0  6.312763e+02  1.625875e+03     0.00
# actor_1_facebook_likes     4909.0  6.494488e+03  1.510699e+04     0.00
# gross                      4054.0  4.764451e+07  6.737255e+07   162.00
# num_voted_users            4916.0  8.264492e+04  1.383222e+05     5.00
# cast_total_facebook_likes  4916.0  9.579816e+03  1.816432e+04     0.00
# facenumber_in_poster       4903.0  1.377320e+00  2.023826e+00     0.00
# num_user_for_reviews       4895.0  2.676688e+02  3.729348e+02     1.00
# budget                     4432.0  3.654749e+07  1.002427e+08   218.00
# title_year                 4810.0  2.002448e+03  1.245398e+01  1916.00
# ...

# %%
movie_df.min(skipna=False)
# Out:
# num_critic_for_reviews       NaN
# duration                     NaN
# director_facebook_likes      NaN
# actor_3_facebook_likes       NaN
# actor_1_facebook_likes       NaN
# gross                        NaN
# num_voted_users              5.0
# cast_total_facebook_likes    0.0
# facenumber_in_poster         NaN
# num_user_for_reviews         NaN
# budget                       NaN
# title_year                   NaN
# actor_2_facebook_likes       NaN
# imdb_score                   1.6
# aspect_ratio                 NaN
# movie_facebook_likes         0.0
# dtype: float64

# %%
muv.isnull().sum().sum()
# Out:
# 2654

# %%
muv.isnull().any().any()
# Out:
# True

# %%
movie_df[['color', 'movie_title', 'color']].max()
# Out:
# Series([], dtype: float64)

# %%
movie_df.select_dtypes(include='object').fillna('').max()
# Out:
# color                                                          Color
# director_name                                          Étienne Faure
# actor_2_name                                           Zubaida Sahar
# genres                                                       Western
# actor_1_name                                           Óscar Jaenada
# movie_title                                                 Æon Flux
# actor_3_name                                           Óscar Jaenada
# plot_keywords                                    zombie|zombie spoof
# movie_imdb_link    http://www.imdb.com/title/tt5574490/?ref_=fn_t...
# language                                                        Zulu
# country                                                 West Germany
# content_rating                                                     X
# dtype: object

# %%
college=pd.read_csv('C:\\Users\\287910031\9781839213106_Code\\data\\college.csv',index_col='INSTNM')

# %%
college_ugds=college.filter(like='UGDS_')

# %%
college_ugds
# Out:
#                                                     UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University                                0.0333      0.9353
# University of Alabama at Birmingham                     0.5922      0.2600
# Amridge University                                      0.2990      0.4192
# University of Alabama in Huntsville                     0.6988      0.1255
# Alabama State University                                0.0158      0.9208
# The University of Alabama                               0.7825      0.1119
# Central Alabama Community College                       0.7255      0.2613
# Athens State University                                 0.7823      0.1200
# Auburn University at Montgomery                         0.5328      0.3376
# Auburn University                                       0.8507      0.0704
# Birmingham Southern College                             0.7983      0.1102
# ...

# %%
college_ugds.loc['Northwest-Shoals Community College'].round(2)
# Out:
# UGDS_WHITE    0.79
# UGDS_BLACK    0.12
# UGDS_HISP     0.03
# UGDS_ASIAN    0.00
# UGDS_AIAN     0.01
# UGDS_NHPI     0.00
# UGDS_2MOR     0.00
# UGDS_NRA      0.00
# UGDS_UNKN     0.03
# Name: Northwest-Shoals Community College, dtype: float64

# %%
(college_ugds.loc['Northwest-Shoals Community College']+0.0001).round(2)
# Out:
# UGDS_WHITE    0.79
# UGDS_BLACK    0.13
# UGDS_HISP     0.03
# UGDS_ASIAN    0.00
# UGDS_AIAN     0.01
# UGDS_NHPI     0.00
# UGDS_2MOR     0.00
# UGDS_NRA      0.00
# UGDS_UNKN     0.03
# Name: Northwest-Shoals Community College, dtype: float64

# %%
college_ugds_rounds=(college_ugds+0.00501)//0.01/100

# %%
college_ugds_rounds2=(college_ugds+0.00001).round(2)

# %%
college_ugds_rounds.equals(college_ugds_rounds2)
# Out:
# True

# %%
np.nan==np.nan
# Out:
# False

# %%
None==None
# Out:
# True

# %%
5 >=np.nan
# Out:
# False

# %%
np.nan< 5
# Out:
# False

# %%
np.nan!=5
# Out:
# True

# %%
college=pd.read_csv('C:\\Users\\287910031\9781839213106_Code\\data\\college.csv',index_col='INSTNM')

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
college_ugds=college.filter(like='UGDS_')

# %%
college_ugds==0.009
# Out:
#                                                     UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University                                 False       False
# University of Alabama at Birmingham                      False       False
# Amridge University                                       False       False
# University of Alabama in Huntsville                      False       False
# Alabama State University                                 False       False
# The University of Alabama                                False       False
# Central Alabama Community College                        False       False
# Athens State University                                  False       False
# Auburn University at Montgomery                          False       False
# Auburn University                                        False       False
# Birmingham Southern College                              False       False
# ...

# %%
a_college=college_ugds==college_ugds

# %%
a_college.all()
# Out:
# UGDS_WHITE    False
# UGDS_BLACK    False
# UGDS_HISP     False
# UGDS_ASIAN    False
# UGDS_AIAN     False
# UGDS_NHPI     False
# UGDS_2MOR     False
# UGDS_NRA      False
# UGDS_UNKN     False
# dtype: bool

# %%
(college_ugds==np.nan).sum()
# Out:
# UGDS_WHITE    0
# UGDS_BLACK    0
# UGDS_HISP     0
# UGDS_ASIAN    0
# UGDS_AIAN     0
# UGDS_NHPI     0
# UGDS_2MOR     0
# UGDS_NRA      0
# UGDS_UNKN     0
# dtype: int64

# %%
college_ugds.isna().sum()
# Out:
# UGDS_WHITE    661
# UGDS_BLACK    661
# UGDS_HISP     661
# UGDS_ASIAN    661
# UGDS_AIAN     661
# UGDS_NHPI     661
# UGDS_2MOR     661
# UGDS_NRA      661
# UGDS_UNKN     661
# dtype: int64

# %%
college_ugds.equals(college_ugds)
# Out:
# True

# %%
college_ugds.count()
# Out:
# UGDS_WHITE    6874
# UGDS_BLACK    6874
# UGDS_HISP     6874
# UGDS_ASIAN    6874
# UGDS_AIAN     6874
# UGDS_NHPI     6874
# UGDS_2MOR     6874
# UGDS_NRA      6874
# UGDS_UNKN     6874
# dtype: int64

# %%
college_ugds.count(axis='columns')
# Out:
# INSTNM
# Alabama A & M University                                  9
# University of Alabama at Birmingham                       9
# Amridge University                                        9
# University of Alabama in Huntsville                       9
# Alabama State University                                  9
# The University of Alabama                                 9
# Central Alabama Community College                         9
# Athens State University                                   9
# Auburn University at Montgomery                           9
# Auburn University                                         9
# Birmingham Southern College                               9
# Chattahoochee Valley Community College                    9
# Concordia College Alabama                                 9
# South University-Montgomery                               9
# Enterprise State Community College                        9
# ...

# %%
college_ugds.count(axis='index')
# Out:
# UGDS_WHITE    6874
# UGDS_BLACK    6874
# UGDS_HISP     6874
# UGDS_ASIAN    6874
# UGDS_AIAN     6874
# UGDS_NHPI     6874
# UGDS_2MOR     6874
# UGDS_NRA      6874
# UGDS_UNKN     6874
# dtype: int64

# %%
college_ugds.sum(axis='columns').head()
# Out:
# INSTNM
# Alabama A & M University               1.0000
# University of Alabama at Birmingham    0.9999
# Amridge University                     1.0000
# University of Alabama in Huntsville    1.0000
# Alabama State University               1.0000
# dtype: float64

# %%
college_ugds.median(axis='columns').head()
# Out:
# INSTNM
# Alabama A & M University               0.0055
# University of Alabama at Birmingham    0.0283
# Amridge University                     0.0034
# University of Alabama in Huntsville    0.0350
# Alabama State University               0.0121
# dtype: float64

# %%
college_ugds.cumsum(axis='columns').head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9686     0.9741
# University of Alabama at Birmingham      0.5922      0.8522     0.8805
# Amridge University                       0.2990      0.7182     0.7251
# University of Alabama in Huntsville      0.6988      0.8243     0.8625
# Alabama State University                 0.0158      0.9366     0.9487
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.9760     0.9784     0.9803
# University of Alabama at Birmingham      0.9323     0.9345     0.9352
# Amridge University                       0.7285     0.7285     0.7285
# University of Alabama in Huntsville      0.9001     0.9144     0.9146
# Alabama State University                 0.9506     0.9516     0.9522
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
pd.read_csv('C:\\Users\\287910031\9781839213106_Code\\data\\college_diversity.csv')
# Out:
#                                               School  Diversity Index
# 0             Rutgers University--Newark  Newark, NJ             0.76
# 1            Andrews University  Berrien Springs, MI             0.74
# 2                  Stanford University  Stanford, CA             0.74
# 3                 University of Houston  Houston, TX             0.74
# 4     University of Nevada--Las Vegas  Las Vegas, NV             0.74
# 5     University of San Francisco  San Francisco, CA             0.74
# 6  San Francisco State University  San Francisco, CA             0.73
# 7       University of Illinois--Chicago  Chicago, IL             0.73
# 8     New Jersey Institute of Technology  Newark, NJ             0.72
# 9               Texas Woman's University  Denton, TX             0.72

# %%
college_ugds.isnull().sum(axis='columns').sort_values(ascending=False).head()
# Out:
# INSTNM
# Excel Learning Center-San Antonio South         9
# Philadelphia College of Osteopathic Medicine    9
# Assemblies of God Theological Seminary          9
# Episcopal Divinity School                       9
# Phillips Graduate Institute                     9
# dtype: int64

# %%
college_ugds=college_ugds.dropna(how="all")

# %%
college_ugds.isna().sum()
# Out:
# UGDS_WHITE    0
# UGDS_BLACK    0
# UGDS_HISP     0
# UGDS_ASIAN    0
# UGDS_AIAN     0
# UGDS_NHPI     0
# UGDS_2MOR     0
# UGDS_NRA      0
# UGDS_UNKN     0
# dtype: int64

# %%
college_ugds.ge(0.15)
# Out:
#                                                     UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University                                 False        True
# University of Alabama at Birmingham                       True        True
# Amridge University                                        True        True
# University of Alabama in Huntsville                       True       False
# Alabama State University                                 False        True
# The University of Alabama                                 True       False
# Central Alabama Community College                         True        True
# Athens State University                                   True       False
# Auburn University at Montgomery                           True        True
# Auburn University                                         True       False
# Birmingham Southern College                               True       False
# ...

# %%
college_div_met=college_ugds.ge(0.15).sum(axis='columns')

# %%
college_div_met.head()
# Out:
# INSTNM
# Alabama A & M University               1
# University of Alabama at Birmingham    2
# Amridge University                     3
# University of Alabama in Huntsville    1
# Alabama State University               1
# dtype: int64

# %%
college_div_met.value_counts()
# Out:
# 1    3042
# 2    2884
# 3     876
# 4      63
# 0       7
# 5       2
# dtype: int64

# %%
college_div_met.sort_values(ascending=False).head()
# Out:
# INSTNM
# Regency Beauty Institute-Austin          5
# Central Texas Beauty College-Temple      5
# Sullivan and Cogliano Training Center    4
# Ambria College of Nursing                4
# Berkeley College-New York                4
# dtype: int64

# %%
college_ugds.loc[['Regency Beauty Institute-Austin','Central Texas Beauty College-Temple']]
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Regency Beauty Institute-Austin          0.1867      0.2133     0.1600
# Central Texas Beauty College-Temple      0.1616      0.2323     0.2626
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Regency Beauty Institute-Austin          0.0000        0.0        0.0
# Central Texas Beauty College-Temple      0.0202        0.0        0.0
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# Regency Beauty Institute-Austin         0.1733       0.0     0.2667
# Central Texas Beauty College-Temple     0.1717       0.0     0.1515

# %%
us_news_top=['Regency Beauty Institute-Austin','Central Texas Beauty College-Temple',
             'Sullivan and Cogliano Training Center','Ambria College of Nursing',
            'Berkeley College-New York']

# %%
college_ugds.loc[us_news_top]
# Out:
#                                        UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Regency Beauty Institute-Austin            0.1867      0.2133     0.1600
# Central Texas Beauty College-Temple        0.1616      0.2323     0.2626
# Sullivan and Cogliano Training Center      0.2392      0.2169     0.3126
# Ambria College of Nursing                  0.3123      0.1990     0.1940
# Berkeley College-New York                  0.0754      0.2719     0.2067
#
#                                        UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Regency Beauty Institute-Austin            0.0000     0.0000     0.0000
# Central Texas Beauty College-Temple        0.0202     0.0000     0.0000
# Sullivan and Cogliano Training Center      0.0080     0.0096     0.0016
# Ambria College of Nursing                  0.2670     0.0025     0.0101
# Berkeley College-New York                  0.0308     0.0046     0.0032
#
#                                        UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# ...

# %%
college_ugds.max(axis='columns').sort_values(ascending=False).head()
# Out:
# INSTNM
# Dewey University-Manati                     1.0
# Yeshiva and Kollel Harbotzas Torah          1.0
# Mr Leon's School of Hair Design-Lewiston    1.0
# Dewey University-Bayamon                    1.0
# Shepherds Theological Seminary              1.0
# dtype: float64
